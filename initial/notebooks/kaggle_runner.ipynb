# %% [markdown]
# # Transferability runner — thesis-mhealthBefore running, in the right-hand panel:**Accelerator = GPU T4 x2** (or P100), and **Internet = On**.

# %%
GITHUB_USER = "academiaprosanta"REPO        = "thesis-mhealth"SUBDIR      = "initial"          # the code lives in this subfolder!pip install -q medmnist

# %%
# Clone a fresh copy of the repo every run, then work inside initial/import shutil, sys, osROOT = f"/kaggle/working/{REPO}"shutil.rmtree(ROOT, ignore_errors=True)!git clone -q https://github.com/{GITHUB_USER}/{REPO}.git {ROOT}PROJ = f"{ROOT}/{SUBDIR}"sys.path.insert(0, PROJ)os.chdir(PROJ)print("working in:", os.getcwd())!ls

# %%
import torchprint("GPU available:", torch.cuda.is_available())print("device:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "NONE")

# %% [markdown]
# ## Smoke test — 3 datasets, ~4 minutesRun this first, every time. It catches bugs before they cost an hour.

# %%
# !python scripts/01_geometry.py --smoke!python scripts/02_transfer_matrix.py --smoke --epochs 2!python scripts/03_build_design_matrix.py --smoke!python scripts/04_regression.py --smoke --n-perm 50

# %% [markdown]
# ## Real run — 11 datasetsOnly once the smoke test passes cleanly.

# %%
# !python scripts/01_geometry.py

# %%
# !python scripts/02_transfer_matrix.py

# %%
# !python scripts/03_build_design_matrix.py

# %% [markdown]
# ## Push results back to GitHubNeeds a secret named `GITHUB_TOKEN` (Add-ons -> Secrets).

# %%
from kaggle_secrets import UserSecretsClientTOKEN = UserSecretsClient().get_secret("GITHUB_TOKEN")os.chdir(ROOT)                       # git commands run at the repo root!git config user.email "you@university.edu"!git config user.name  "Your Name"!git remote set-url origin https://oauth2:{TOKEN}@github.com/{GITHUB_USER}/{REPO}.git!git add {SUBDIR}/results!git commit -q -m "kaggle run: geometry + transfer matrix" || echo "nothing new to commit"!git push -q origin HEAD:mainos.chdir(PROJ)print("pushed")

# %% [markdown]
# Now on your laptop: `git pull`, then `python scripts/04_regression.py` from inside `initial/`.
