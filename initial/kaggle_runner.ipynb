# %% [markdown]
# # Transferability runnerThis notebook does almost nothing itself. It clones your GitHub repo and callsthe code in it. All real logic lives in `src/` on your laptop.**Before running:** in the right-hand panel set **Accelerator = GPU** and**Internet = On**.

# %%
GITHUB_USER = "YOURNAME"          # <-- edit thisREPO        = "transferability"!pip install -q medmnist

# %%
# Clone a fresh copy of your code every run.import shutil, sys, ospath = f"/kaggle/working/{REPO}"shutil.rmtree(path, ignore_errors=True)!git clone -q https://github.com/{GITHUB_USER}/{REPO}.git {path}sys.path.insert(0, path)os.chdir(path)print(open(f"{path}/README.md").readline())

# %% [markdown]
# ## Step 1 — smoke test (3 datasets, ~4 minutes)Always run this first. It catches bugs cheaply.

# %%
# !python scripts/01_geometry.py --smoke!python scripts/02_transfer_matrix.py --smoke --epochs 2!python scripts/03_build_design_matrix.py --smoke

# %% [markdown]
# ## Step 2 — the real run (~1 hour)Only once the smoke test passes.

# %%
# !python scripts/01_geometry.py

# %%
# !python scripts/02_transfer_matrix.py

# %%
# !python scripts/03_build_design_matrix.py

# %% [markdown]
# ## Step 3 — push results back to GitHubNeeds a `GITHUB_TOKEN` secret: **Add-ons -> Secrets -> Add a secret**.

# %%
from kaggle_secrets import UserSecretsClientTOKEN = UserSecretsClient().get_secret("GITHUB_TOKEN")!git config user.email "you@university.edu"!git config user.name  "Your Name"!git remote set-url origin https://oauth2:{TOKEN}@github.com/{GITHUB_USER}/{REPO}.git!git add results/!git commit -q -m "kaggle run: geometry + transfer matrix" || echo "nothing to commit"!git push -q origin HEAD:mainprint("pushed")

# %% [markdown]
# Now on your laptop: `git pull`, then `python scripts/04_regression.py`.
